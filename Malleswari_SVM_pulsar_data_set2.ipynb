# %% [markdown]
# # pulsar_data_train data set EDA set2

# %% [markdown]
# ## importing necessary libraries and reading the csv file

# %%
# pandas is used to store data in a data frame format we used
import pandas as pd
#current file is stored in my os,so we can access that file
import os

# %%
pulsar_data_train=pd.read_csv("pulsar_data_train.csv")

# %% [markdown]
# ### To check the what are columns available in the  file

# %%
pulsar_data_train.columns
# Out:
# Index([' Mean of the integrated profile',
#        ' Standard deviation of the integrated profile',
#        ' Excess kurtosis of the integrated profile',
#        ' Skewness of the integrated profile', ' Mean of the DM-SNR curve',
#        ' Standard deviation of the DM-SNR curve',
#        ' Excess kurtosis of the DM-SNR curve', ' Skewness of the DM-SNR curve',
#        'target_class'],
#       dtype='object')

# %%
# to see the what are the columns available in the data set and values  are correct format or not
pulsar_data_train.head()
# Out:
#     Mean of the integrated profile  \
# 0                       121.156250
# 1                        76.968750
# 2                       130.585938
# 3                       156.398438
# 4                        84.804688
#
#     Standard deviation of the integrated profile  \
# 0                                      48.372971
# 1                                      36.175557
# 2                                      53.229534
# 3                                      48.865942
# 4                                      36.117659
#
#     Excess kurtosis of the integrated profile  \
# 0                                    0.375485
# 1                                    0.712898
# 2                                    0.133408
# 3                                   -0.215989
# 4                                    0.825013
#
#     Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                            -0.013165                   3.168896
# 1                             3.388719                   2.399666
# 2                            -0.297242                   2.743311
# 3                            -0.171294                  17.471572
# 4                             3.274125                   2.790134
#
#     Standard deviation of the DM-SNR curve  \
# 0                                18.399367
# 1                                17.570997
# 2                                22.362553
# 3                                      NaN
# 4                                20.618009
#
#     Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                              7.449874                      65.159298
# 1                              9.414652                     102.722975
# 2                              8.508364                      74.031324
# 3                              2.958066                       7.197842
# 4                              8.405008                      76.291128
#
#    target_class
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %% [markdown]
# ## to check the file size and how many columns are available

# %%
pulsar_data_train.shape
# Out:
# (12528, 9)

# %% [markdown]
# ### so total 9 columns and 12528 rows

# %% [markdown]
# ## To check the information about data and datatypes  is there any categorical data is there or not

# %%
pulsar_data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12528 entries, 0 to 12527
# Data columns (total 9 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0    Mean of the integrated profile                12528 non-null  float64
#  1    Standard deviation of the integrated profile  12528 non-null  float64
#  2    Excess kurtosis of the integrated profile     10793 non-null  float64
#  3    Skewness of the integrated profile            12528 non-null  float64
#  4    Mean of the DM-SNR curve                      12528 non-null  float64
#  5    Standard deviation of the DM-SNR curve        11350 non-null  float64
#  6    Excess kurtosis of the DM-SNR curve           12528 non-null  float64
#  7    Skewness of the DM-SNR curve                  11903 non-null  float64
#  8   target_class                                   12528 non-null  int64
# dtypes: float64(8), int64(1)
# memory usage: 881.0 KB

# %% [markdown]
# ## is any null values are there or not

# %%
pulsar_data_train.isnull().sum()
# Out:
#  Mean of the integrated profile                     0
#  Standard deviation of the integrated profile       0
#  Excess kurtosis of the integrated profile       1735
#  Skewness of the integrated profile                 0
#  Mean of the DM-SNR curve                           0
#  Standard deviation of the DM-SNR curve          1178
#  Excess kurtosis of the DM-SNR curve                0
#  Skewness of the DM-SNR curve                     625
# target_class                                        0
# dtype: int64

# %% [markdown]
# ### in 3 columns have null values we have to impute those for that we can see the statistics data

# %%
pulsar_data_train.describe()
# Out:
#         Mean of the integrated profile  \
# count                     12528.000000
# mean                        111.041841
# std                          25.672828
# min                           5.812500
# 25%                         100.871094
# 50%                         115.183594
# 75%                         127.109375
# max                         189.734375
#
#         Standard deviation of the integrated profile  \
# count                                   12528.000000
# mean                                       46.521437
# std                                         6.801077
# min                                        24.772042
# 25%                                        42.362222
# 50%                                        46.931022
# 75%                                        50.979103
# max                                        91.808628
#
#         Excess kurtosis of the integrated profile  \
# count                                10793.000000
# mean                                     0.478548
# std                                      1.064708
# min                                     -1.738021
# 25%                                      0.024652
# 50%                                      0.223678
# 75%                                      0.473125
# max                                      8.069522
#
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# count                         12528.000000               12528.000000
# mean                              1.778431                  12.674758
# std                               6.208450                  29.613230
# min                              -1.791886                   0.213211
# 25%                              -0.188142                   1.910535
# 50%                               0.203317                   2.792642
# 75%                               0.932374                   5.413253
# max                              68.101622                 222.421405
#
#         Standard deviation of the DM-SNR curve  \
# count                             11350.000000
# mean                                 26.351318
# std                                  19.610842
# min                                   7.370432
# 25%                                  14.404353
# 50%                                  18.412402
# 75%                                  28.337418
# max                                 110.642211
#
#         Excess kurtosis of the DM-SNR curve   Skewness of the DM-SNR curve  \
# count                          12528.000000                   11903.000000
# mean                               8.333489                     105.525779
# std                                4.535783                     107.399585
# min                               -3.139270                      -1.976976
# 25%                                5.803063                      35.199899
# 50%                                8.451097                      83.126301
# 75%                               10.727927                     139.997850
# max                               34.539844                    1191.000837
#
#        target_class
# count  12528.000000
# mean       0.092034
# std        0.289085
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# #### I am imputing the median of Excess kurtosis of the integrated profile and Standard deviation of the DM-SNR curve  because Excess kurtosis of the integrated profile has mean and median are near

# %%
pulsar_data_train[' Excess kurtosis of the integrated profile']=pulsar_data_train[' Excess kurtosis of the integrated profile'].fillna(
    pulsar_data_train[' Excess kurtosis of the integrated profile'].median())

# %%
pulsar_data_train[' Standard deviation of the DM-SNR curve']=pulsar_data_train[' Standard deviation of the DM-SNR curve'].fillna(
    pulsar_data_train[' Standard deviation of the DM-SNR curve'].median())

# %% [markdown]
# ####  Skewness of the DM-SNR curve  column is removed because very less number  compare to data size

# %%
pulsar_data_train=pulsar_data_train.dropna()

# %%
x=pulsar_data_train

# %%
x
# Out:
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                                -0.013165                   3.168896
# 1                                 3.388719                   2.399666
# 2                                -0.297242                   2.743311
# 3                                -0.171294                  17.471572
# 4                                 3.274125                   2.790134
# ...                                    ...                        ...
# 12523                            -0.556021                   7.186455
# 12524                             0.226757                   6.140468
# 12525                             0.433088                   0.785117
# 12526                            -0.226726                   3.859532
# 12527                             0.184797                   0.769231
#
#         Standard deviation of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                                    18.399367                      65.159298
# 1                                    17.570997                     102.722975
# 2                                    22.362553                      74.031324
# 3                                    18.412402                       7.197842
# 4                                    20.618009                      76.291128
# ...                                        ...                            ...
# 12523                                29.308266                      21.725143
# 12524                                18.412402                      34.357282
# 12525                                11.628149                     312.204325
# 12526                                21.501505                      62.334018
# 12527                                11.792603                     329.548016
#
#        target_class  standard dev and kurtosis
# 0                 0                  18.163309
# 1                 0                  25.789477
# 2                 0                   7.101261
# 3                 0                 -10.554486
# 4                 0                  29.797530
# ...             ...                        ...
# 12523             0                  -0.660362
# 12524             0                  10.207324
# 12525             0                  28.670472
# 12526             0                  -4.491057
# 12527             0                  17.472389
#
# [11903 rows x 6 columns]

# %% [markdown]
#  #### to check the what type of target variable have

# %%
# to importing the needed libraries for plotting the data
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#to plot target variable to see of the data is balanced or not
sns.distplot(pulsar_data_train['target_class'])
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='target_class', ylabel='Density'>

# %% [markdown]
# #### the data is imbalanced data  because compare to 0 to 1, 1 has less number of data point to 0

# %% [markdown]
# ### to check  if any outliers  are there or not in  the data, for that we use box plot it describe the 50% percentile data

# %%
plt.figure(figsize= (12,8)) 
sns.boxplot(data=pulsar_data_train)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### it is littile bit mess so i can compare the box plot and hist plot parallel

# %%
plt.figure(figsize=(12,35))
plt.rcParams.update({'font.size': 12})

for i in enumerate(pulsar_data_train.columns[:-1]):
    
    plt.subplot(8,2,(2*i[0])+1);
    pulsar_data_train[i[1]].hist(grid=False,xlabelsize=12, lw=1.5, ylabelsize=14, edgecolor = "black");
    plt.title(f"Distribution of {i[1]}",fontsize=14);
    plt.xlabel(f"{i[1]}", fontsize = 12);
    plt.tight_layout(h_pad=2, w_pad=2)
    
    plt.subplot(8,2,(2*i[0])+2);
    sns.boxplot(pulsar_data_train[i[1]]);
    plt.title(f"{i[1]} Boxplot", fontsize=14);
    plt.tight_layout(h_pad=2, w_pad=2)
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### in these all columns has outliers because the dat is imbalanced  if i can apply quartile  target 1 is missed, z-score all rows are missed so we can deal with outliers

# %% [markdown]
# ### To check the bivariation  of variable by using the pair plot

# %%
sns.pairplot(pulsar_data_train,hue='target_class')

# %% [markdown]
# ### To check the univariation of the variable of Standard deviation of the integrated profile by using the histplot

# %%
sns.histplot(pulsar_data_train[' Standard deviation of the integrated profile'])
# Out:
# <AxesSubplot:xlabel=' Standard deviation of the integrated profile', ylabel='Count'>

# %%
# To check the distribution plot for frequence
sns.distplot(pulsar_data_train[' Mean of the integrated profile'] )
sns.distplot(pulsar_data_train[' Standard deviation of the integrated profile'] )
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel=' Standard deviation of the integrated profile', ylabel='Density'>

# %%
sns.distplot(pulsar_data_train[' Excess kurtosis of the integrated profile'] )
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel=' Excess kurtosis of the integrated profile', ylabel='Density'>

# %%
sns.distplot(pulsar_data_train[' Skewness of the integrated profile'] )
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel=' Skewness of the integrated profile', ylabel='Density'>

# %% [markdown]
# ### To check the correlation between the variables by using the heat map

# %%
sns.heatmap(pulsar_data_train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Here there are some negative corelation is there so i can check the VIF for more clarity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif_data = pd.DataFrame()
vif_data["feature"] = pulsar_data_train.columns
vif_data["VIF"] = [variance_inflation_factor(pulsar_data_train.values, i)
                          for i in range(len(pulsar_data_train.columns))]
  
print(vif_data)
# Out:
#                                          feature        VIF
# 0                 Mean of the integrated profile  52.510088
# 1   Standard deviation of the integrated profile  61.020120
# 2      Excess kurtosis of the integrated profile   6.453039
# 3             Skewness of the integrated profile   5.129736
# 4                       Mean of the DM-SNR curve   4.047748
# 5         Standard deviation of the DM-SNR curve  10.062632
# 6            Excess kurtosis of the DM-SNR curve  78.193586
# 7                   Skewness of the DM-SNR curve  23.844125
# 8                                   target_class   2.783256

# %% [markdown]
# ### By observing the above cells Excess kurtosis of the DM-SNR curve and Mean of the integrated profile has more variance and correlation to the target variable is also negative so i delete both columns

# %%
pulsar_data_train=pulsar_data_train.drop([' Mean of the integrated profile',' Excess kurtosis of the DM-SNR curve'],axis=1)

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = pulsar_data_train.columns
vif_data["VIF"] = [variance_inflation_factor(pulsar_data_train.values, i)
                          for i in range(len(pulsar_data_train.columns))]
  
print(vif_data)
# Out:
#                                          feature       VIF
# 0   Standard deviation of the integrated profile  7.717049
# 1      Excess kurtosis of the integrated profile  5.534351
# 2             Skewness of the integrated profile  4.908004
# 3                       Mean of the DM-SNR curve  2.721413
# 4         Standard deviation of the DM-SNR curve  8.395360
# 5                   Skewness of the DM-SNR curve  2.647901
# 6                                   target_class  2.666798

# %% [markdown]
# ### i will again check the VIF score and new column is added  to data frame for multiplication of both Standard deviation of the integrated profile and Excess kurtosis of the integrated profile and don't adding for those  columns to IVF because some values are more than 5

# %%
pulsar_data_train['standard dev and kurtosis']=pulsar_data_train[' Standard deviation of the integrated profile']*pulsar_data_train[' Excess kurtosis of the integrated profile']

# %% [markdown]
# ### dropping the Standard deviation of the integrated profile and Excess kurtosis of the integrated profile columns

# %%
pulsar_data_train=pulsar_data_train.drop([' Standard deviation of the integrated profile',' Excess kurtosis of the integrated profile'],axis=1)

# %% [markdown]
# ### applying VIF again

# %%
vif_data = pd.DataFrame()
vif_data["feature"] = pulsar_data_train.columns
vif_data["VIF"] = [variance_inflation_factor(pulsar_data_train.values, i)
                          for i in range(len(pulsar_data_train.columns))]
  
print(vif_data)
# Out:
#                                    feature       VIF
# 0       Skewness of the integrated profile  3.241798
# 1                 Mean of the DM-SNR curve  2.465898
# 2   Standard deviation of the DM-SNR curve  3.014815
# 3             Skewness of the DM-SNR curve  1.314409
# 4                             target_class  2.780000
# 5                standard dev and kurtosis  3.949181

# %% [markdown]
# ### so these  values are less than 5 so we can feed these features to  our model will predict the correct output

# %%
pulsar_data_train
# Out:
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                                -0.013165                   3.168896
# 1                                 3.388719                   2.399666
# 2                                -0.297242                   2.743311
# 3                                -0.171294                  17.471572
# 4                                 3.274125                   2.790134
# ...                                    ...                        ...
# 12523                            -0.556021                   7.186455
# 12524                             0.226757                   6.140468
# 12525                             0.433088                   0.785117
# 12526                            -0.226726                   3.859532
# 12527                             0.184797                   0.769231
#
#         Standard deviation of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                                    18.399367                      65.159298
# 1                                    17.570997                     102.722975
# 2                                    22.362553                      74.031324
# 3                                    18.412402                       7.197842
# 4                                    20.618009                      76.291128
# ...                                        ...                            ...
# 12523                                29.308266                      21.725143
# 12524                                18.412402                      34.357282
# 12525                                11.628149                     312.204325
# 12526                                21.501505                      62.334018
# 12527                                11.792603                     329.548016
#
#        target_class  standard dev and kurtosis
# 0                 0                  18.163309
# 1                 0                  25.789477
# 2                 0                   7.101261
# 3                 0                 -10.554486
# 4                 0                  29.797530
# ...             ...                        ...
# 12523             0                  -0.660362
# 12524             0                  10.207324
# 12525             0                  28.670472
# 12526             0                  -4.491057
# 12527             0                  17.472389
#
# [11903 rows x 6 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier , GradientBoostingClassifier
from sklearn.linear_model import LinearRegression,Ridge,Lasso,RidgeCV
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor 
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor

from sklearn.preprocessing import Normalizer , scale
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFECV
from sklearn.model_selection import GridSearchCV , KFold , cross_val_score

from sklearn.preprocessing import MinMaxScaler , StandardScaler,  LabelEncoder
from sklearn.metrics import mean_squared_log_error,mean_squared_error, r2_score,mean_absolute_error 
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score

# %%
X = pulsar_data_train.drop(['target_class'], axis=1)
y = pulsar_data_train['target_class']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=66)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
#modeling alogorithms
R2_Scores = []
models = ['Linear Regression' , 'Lasso Regression' , 'AdaBoost Regression' , 'Ridge Regression' , 'GradientBoosting Regression',
          'RandomForest Regression' ,
         'KNeighbours Regression','DecisionTreeClassifier','svm',"linearSVM","LogisticRegression"]

# %%
#linear regression
clf_lr = LinearRegression()
clf_lr.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_lr, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_lr.predict(X_test)
#print('')
#print('####### Linear Regression #######')
#print('Score : %.4f' % clf_lr.score(X_test, y_test))
#print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

#print('')
#print('MSE    : %0.2f ' % mse)
#print('MAE    : %0.2f ' % mae)
#print('RMSE   : %0.2f ' % rmse)
#print('R2     : %0.2f ' % r2)
#print("Linear Regression Coefficients: \n")
#print(clf_lr.coef_)

R2_Scores.append(r2)

import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns

x_train = X_train
y_train_2 = y_train
x_train_1 = sm.add_constant(x_train)
model = sm.OLS(y_train_2, x_train_1)
results = model.fit()
#print("hi",results.summary())
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished

# %%
#lasso 
clf_la = Lasso(normalize=True)
clf_la.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_la, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_la.predict(X_test)
#print('')
#print('###### Lasso Regression ######')
#print('Score : %.4f' % clf_la.score(X_test, y_test))
#print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

#print("Lasso Regression Coefficients: \n")
#print(clf_la.coef_)
#print('')
#print('MSE    : %0.2f ' % mse)
#print('MAE    : %0.2f ' % mae)
#print('RMSE   : %0.2f ' % rmse)
#print('R2     : %0.2f ' % r2)

R2_Scores.append(r2)
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Lasso())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * np.sqrt(n_samples).
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished

# %%
#adaboast
clf_ar = AdaBoostRegressor(n_estimators=1000)
clf_ar.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_ar, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_ar.predict(X_test)
#print('')
#print('###### AdaBoost Regression ######')
#print('Score : %.4f' % clf_ar.score(X_test, y_test))
#print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)


#print('')
#print('MSE    : %0.2f ' % mse)
#print('MAE    : %0.2f ' % mae)
#print('RMSE   : %0.2f ' % rmse)
#print('R2     : %0.2f ' % r2)

R2_Scores.append(r2)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    1.0s finished

# %%
#Ridge
clf_rr = Ridge(normalize=True)
clf_rr.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_rr, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_rr.predict(X_test)
#print('')
#print('###### Ridge Regression ######')
#print('Score : %.4f' % clf_rr.score(X_test, y_test))
#print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

#print("Ridge Regression Coefficients: \n")
#print(clf_rr.coef_)

#print('')
#print('MSE    : %0.2f ' % mse)
#print('MAE    : %0.2f ' % mae)
#print('RMSE   : %0.2f ' % rmse)
#print('R2     : %0.2f ' % r2)

R2_Scores.append(r2)
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), Ridge())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
# Set parameter alpha to: original_alpha * n_samples.
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished

# %%
#graiden boosting
clf_gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1,max_depth=1, random_state=0, loss='ls',verbose = 1)
clf_gbr.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_gbr, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_gbr.predict(X_test)
#print('')
#print('###### Gradient Boosting Regression #######')
#print('Score : %.4f' % clf_gbr.score(X_test, y_test))
#print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

#print('')
#print('MSE    : %0.2f ' % mse)
#print('MAE    : %0.2f ' % mae)
#print('RMSE   : %0.2f ' % rmse)
#print('R2     : %0.2f ' % r2)

R2_Scores.append(r2)
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
#       Iter       Train Loss   Remaining Time
#          1           0.0729            1.45s
#          2           0.0644            1.23s
#          3           0.0573            0.81s
#          4           0.0513            0.79s
#          5           0.0465            0.94s
#          6           0.0424            0.90s
#          7           0.0390            0.77s
#          8           0.0362            0.85s
#          9           0.0339            0.83s
#         10           0.0319            0.88s
#         20           0.0237            0.90s
#         30           0.0219            0.68s
#         40           0.0213            0.59s
#         50           0.0211            0.49s
#         60           0.0209            0.41s
#         70           0.0209            0.31s
#         80           0.0208            0.21s
#         90           0.0207            0.11s
#        100           0.0207            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.0711            1.59s
#          2           0.0628            1.18s
#          3           0.0559            1.04s
#          4           0.0501            1.15s
#          5           0.0453            1.06s
#          6           0.0414            1.05s
#          7           0.0381            0.89s
#          8           0.0354            0.77s
#          9           0.0330            0.84s
#         10           0.0311            0.82s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
#         20           0.0230            0.61s
#         30           0.0212            0.51s
#         40           0.0207            0.41s
#         50           0.0205            0.35s
#         60           0.0203            0.28s
#         70           0.0203            0.22s
#         80           0.0202            0.15s
#         90           0.0201            0.08s
#        100           0.0201            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.0723            0.29s
#          2           0.0639            0.65s
#          3           0.0570            0.66s
#          4           0.0512            0.49s
#          5           0.0464            0.52s
#          6           0.0424            0.57s
#          7           0.0391            0.56s
#          8           0.0364            0.60s
#          9           0.0341            0.61s
#         10           0.0322            0.62s
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
#         20           0.0240            0.52s
#         30           0.0222            0.49s
#         40           0.0216            0.40s
#         50           0.0214            0.37s
#         60           0.0212            0.29s
#         70           0.0212            0.22s
#         80           0.0211            0.14s
#         90           0.0210            0.07s
#        100           0.0210            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.0739            0.79s
#          2           0.0652            0.78s
#          3           0.0579            1.03s
#          4           0.0519            0.96s
#          5           0.0469            0.91s
#          6           0.0427            1.00s
#          7           0.0392            0.96s
#          8           0.0363            0.92s
#          9           0.0339            0.89s
#         10           0.0320            0.94s
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
#         20           0.0236            0.78s
#         30           0.0218            0.67s
#         40           0.0212            0.55s
#         50           0.0210            0.42s
#         60           0.0209            0.32s
#         70           0.0208            0.25s
#         80           0.0207            0.17s
#         90           0.0206            0.09s
#        100           0.0205            0.00s
#       Iter       Train Loss   Remaining Time
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
#          1           0.0738            1.59s
#          2           0.0652            1.06s
#          3           0.0579            0.96s
#          4           0.0520            0.94s
#          5           0.0470            0.89s
#          6           0.0428            0.85s
#          7           0.0394            0.72s
#          8           0.0366            0.72s
#          9           0.0342            0.71s
#         10           0.0322            0.64s
#         20           0.0238            0.61s
#         30           0.0219            0.55s
#         40           0.0214            0.45s
#         50           0.0211            0.36s
#         60           0.0210            0.29s
#         70           0.0209            0.21s
#         80           0.0208            0.15s
#         90           0.0207            0.07s
#        100           0.0207            0.00s
#       Iter       Train Loss   Remaining Time
#          1           0.0733            1.22s
#          2           0.0646            0.91s
#          3           0.0575            0.60s
#          4           0.0515            0.64s
#          5           0.0465            0.55s
#          6           0.0424            0.45s
#          7           0.0390            0.53s
#          8           0.0362            0.52s
#          9           0.0338            0.52s
#         10           0.0319            0.56s
#         20           0.0236            0.48s
#         30           0.0218            0.46s
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:286: FutureWarning: The loss 'ls' was deprecated in v1.0 and will be removed in version 1.2. Use 'squared_error' which is equivalent.
#   warnings.warn(
#         40           0.0212            0.37s
#         50           0.0210            0.31s
#         60           0.0208            0.25s
#         70           0.0207            0.19s
#         80           0.0207            0.13s
#         90           0.0206            0.07s
#        100           0.0205            0.00s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    3.7s finished

# %%
#random farest
clf_rf = RandomForestRegressor()
clf_rf.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_rf, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_rf.predict(X_test)
#print('')
#print('###### Random Forest ######')
#print('Score : %.4f' % clf_rf.score(X_test, y_test))
#print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

#print('')
#print('MSE    : %0.2f ' % mse)
#print('MAE    : %0.2f ' % mae)
#print('RMSE   : %0.2f ' % rmse)
#print('R2     : %0.2f ' % r2)
R2_Scores.append(r2)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   23.5s finished

# %%
#Kneighbors
clf_knn = KNeighborsRegressor()
clf_knn.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_knn, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_knn.predict(X_test)
#print('')
#print('###### KNeighbours Regression ######')
#print('Score : %.4f' % clf_knn.score(X_test, y_test))
#print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

#print('')
#print('MSE    : %0.2f ' % mse)
#print('MAE    : %0.2f ' % mae)
#print('RMSE   : %0.2f ' % rmse)
#print('R2     : %0.2f ' % r2)
R2_Scores.append(r2)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.1s finished

# %%
#decision trees
from sklearn import tree
clf_Dtr =tree.DecisionTreeClassifier()
clf_Dtr.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_Dtr, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_Dtr.predict(X_test)
#print('')
#print('###### decision tree ######')
#print('Score : %.4f' % clf_Dtr.score(X_test, y_test))
#print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

#print('')
#print('MSE    : %0.2f ' % mse)
#print('MAE    : %0.2f ' % mae)
#print('RMSE   : %0.2f ' % rmse)
#print('R2     : %0.2f ' % r2)
R2_Scores.append(r2)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.4s finished

# %%
#from sklearn import svm
clf_svm =SVC(kernel = 'linear', random_state = 0, C=1.0)
clf_svm.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_svm, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_Dtr.predict(X_test)
#print('')
#print('###### svm ######')
#print('Score : %.4f' % clf_svm.score(X_test, y_test))
#print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

#print('')
#print('MSE    : %0.2f ' % mse)
#print('MAE    : %0.2f ' % mae)
#print('RMSE   : %0.2f ' % rmse)
#print('R2     : %0.2f ' % r2)
R2_Scores.append(r2)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    2.0s finished

# %%
#linearsvm
clf_linsvm =LinearSVC(random_state = 0, C=1.0)
clf_linsvm.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_linsvm, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_linsvm.predict(X_test)
#print('')
#print('###### svm ######')
#print('Score : %.4f' % clf_linsvm.score(X_test, y_test))
#print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

#print('')
#print('MSE    : %0.2f ' % mse)
#print('MAE    : %0.2f ' % mae)
#print('RMSE   : %0.2f ' % rmse)
#print('R2     : %0.2f ' % r2)
R2_Scores.append(r2)
# Out:
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\svm\_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.8s finished

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix

# %%
logreg = LogisticRegression(max_iter = 10000)
logreg.fit(X_train, y_train)
log_predicted= logreg.predict(X_test)

# %%
og_predicted_train = logreg.predict(X_train)
r2=accuracy_score(y_train,log_predicted_train)
print('Confusion Matrix: \n', confusion_matrix(y_train,log_predicted_train))
print('Classification Report: \n', classification_report(y_train,log_predicted_train))
#r2 = r2_score(y_test, y_pred)
print(r2)
R2_Scores.append(r2)
# Out:
# Confusion Matrix:
#  [[8014  636]
#  [ 799   73]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92      8650
#            1       0.10      0.08      0.09       872
#
#     accuracy                           0.85      9522
#    macro avg       0.51      0.51      0.51      9522
# weighted avg       0.84      0.85      0.84      9522
#
# 0.8492963663095988

# %% [markdown]
# ### 1. Pls calculate the performance metrics and interpret them in simple plain English for Dr Kamal
# ## 2. Ultimately, this is a binary classification problem. Can you run a logistic regression, tree- based algorithm/ensemble methods on the same data set and see if this outperforms the SVM?

# %%
compare = pd.DataFrame({'Algorithms' : models , 'R2-Scores' : R2_Scores})
compare.sort_values(by='R2-Scores' ,ascending=False)
#R2_Scores
# Out:
#                      Algorithms  R2-Scores
# 10           LogisticRegression   0.849296
# 5       RandomForest Regression   0.739036
# 6        KNeighbours Regression   0.730258
# 2           AdaBoost Regression   0.725014
# 4   GradientBoosting Regression   0.720674
# 9                     linearSVM   0.663074
# 0             Linear Regression   0.611779
# 3              Ridge Regression   0.535603
# 7        DecisionTreeClassifier   0.527298
# 8                           svm   0.527298
# 1              Lasso Regression  -0.000002

# %% [markdown]
# ### so LogisticRegression 	 will give best result compare to other models

# %%
sns.barplot(x='R2-Scores' , y='Algorithms' , data=compare);

# %% [markdown]
# ## Can you include the “class” as an independent categorical variable and predict the Skewness of the integrated profile using simple linear regression

# %%
 pulsar_data_train
# Out:
#         Skewness of the integrated profile   Mean of the DM-SNR curve  \
# 0                                -0.013165                   3.168896
# 1                                 3.388719                   2.399666
# 2                                -0.297242                   2.743311
# 3                                -0.171294                  17.471572
# 4                                 3.274125                   2.790134
# ...                                    ...                        ...
# 12523                            -0.556021                   7.186455
# 12524                             0.226757                   6.140468
# 12525                             0.433088                   0.785117
# 12526                            -0.226726                   3.859532
# 12527                             0.184797                   0.769231
#
#         Standard deviation of the DM-SNR curve   Skewness of the DM-SNR curve  \
# 0                                    18.399367                      65.159298
# 1                                    17.570997                     102.722975
# 2                                    22.362553                      74.031324
# 3                                    18.412402                       7.197842
# 4                                    20.618009                      76.291128
# ...                                        ...                            ...
# 12523                                29.308266                      21.725143
# 12524                                18.412402                      34.357282
# 12525                                11.628149                     312.204325
# 12526                                21.501505                      62.334018
# 12527                                11.792603                     329.548016
#
#        target_class  standard dev and kurtosis
# 0                 0                  18.163309
# 1                 0                  25.789477
# 2                 0                   7.101261
# 3                 0                 -10.554486
# 4                 0                  29.797530
# ...             ...                        ...
# 12523             0                  -0.660362
# 12524             0                  10.207324
# 12525             0                  28.670472
# 12526             0                  -4.491057
# 12527             0                  17.472389
#
# [11903 rows x 6 columns]

# %%
X = pulsar_data_train.drop([' Skewness of the integrated profile'], axis=1)
y = pulsar_data_train[' Skewness of the integrated profile']

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=66)

# %%
clf_lr1 = LinearRegression()
clf_lr1.fit(X_train , y_train)
accuracies = cross_val_score(estimator = clf_lr1, X = X_train, y = y_train, cv = 5,verbose = 1)
y_pred = clf_lr1.predict(X_test)
print('')
print('####### Linear Regression #######')
print('Score : %.4f' % clf_lr.score(X_test, y_test))
print(accuracies)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred)**0.5
r2 = r2_score(y_test, y_pred)

print('')
print('MSE    : %0.2f ' % mse)
print('MAE    : %0.2f ' % mae)
print('RMSE   : %0.2f ' % rmse)
print('R2     : %0.2f ' % r2)
print("Linear Regression Coefficients: \n")
print(clf_lr.coef_)

x_train = X_train
y_train_2 = y_train
x_train_1 = sm.add_constant(x_train)
model = sm.OLS(y_train_2, x_train_1)
results = model.fit()
print("hi",results.summary())
# Out:
# ####### Linear Regression #######
# Score : -2.5276
# [0.686297   0.67869828 0.65335519 0.64379732 0.64508963]
#
# MSE    : 10.23
# MAE    : 1.60
# RMSE   : 3.20
# R2     : 0.69
# Linear Regression Coefficients:
#
# [ 0.07922527 -0.01282314  0.0617042  -0.00468866  0.13010719]
# hi                                      OLS Regression Results
# ===============================================================================================
# Dep. Variable:      Skewness of the integrated profile   R-squared:                       0.665
# Model:                                             OLS   Adj. R-squared:                  0.665
# Method:                                  Least Squares   F-statistic:                     3778.
# Date:                                 Fri, 17 Feb 2023   Prob (F-statistic):               0.00
# Time:                                         17:06:36   Log-Likelihood:                -25805.
# No. Observations:                                 9522   AIC:                         5.162e+04
# Df Residuals:                                     9516   BIC:                         5.166e+04
# Df Model:                                            5
# Covariance Type:                             nonrobust
# ===========================================================================================================
#                                               coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------
# const                                      -0.8856      0.109     -8.089      0.000      -1.100      -0.671
#  Mean of the DM-SNR curve                   0.0216      0.002     11.169      0.000       0.018       0.025
#  Standard deviation of the DM-SNR curve     0.0009      0.004      0.263      0.793      -0.006       0.008
#  Skewness of the DM-SNR curve               0.0005      0.000      1.241      0.215      -0.000       0.001
# target_class                                5.1571      0.200     25.726      0.000       4.764       5.550
# standard dev and kurtosis                   0.1071      0.002     65.733      0.000       0.104       0.110
# ==============================================================================
# Omnibus:                     7764.220   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           487591.141
# Skew:                           3.476   Prob(JB):                         0.00
# Kurtosis:                      37.360   Cond. No.                         816.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
# C:\Users\nagam\anaconda3\lib\site-packages\sklearn\base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %% [markdown]
# ## please provide feed back
# ## Thank you
